# %% [markdown]
# # Listas

# %% [markdown]
# ### 1. ¿Qué son las listas en Python?

# %% [markdown]
# Las listas son un tipo de dato complejo y particular del lenguaje de programación Python. Una lista se corresponde con una colección arbitraria de objetos. Las listas son similares a estructuras como los arrays en otros lenguajes de programación con la diferencia de que aportan una mayor flexibilidad.

# %% [markdown]
# Las listas en Python se representan con el tipo `list` y la sintaxis que se utiliza para definirlas consiste en indicar una lista de objetos separados entre comas y encerrados entre corchetes: `[obj1, obj2, ..., objn]`

# %%
lista = [1, 2, 3, 4, 5]

# %%
type(lista)
# Out:
# list

# %%
print(lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
lista2 = ["texto1", "texto2", "texto3"]

# %%
type(lista2)
# Out:
# list

# %%
print(lista2)
# Out:
# ['texto1', 'texto2', 'texto3']

# %% [markdown]
# ### 2. Las listas respetan el orden

# %% [markdown]
# Una de las características importantes de las listas es que se corresponden con una colección ordenada de objetos. El orden en el que se especifican los elementos cuando se define una lista es relevante y se mantiene durante toda su vida.

# %%
lista1 = ['t1', 't2', 't3']

# %%
print(lista1)
# Out:
# ['t1', 't2', 't3']

# %%
print(lista1)
# Out:
# ['t1', 't2', 't3']

# %% [markdown]
# **Podemos utilizar los operadores vistos en el tema anterior para comparar listas**

# %%
lista2 = ['t2', 't1', 't3']

# %%
lista1 == lista2
# Out:
# False

# %%
lista1 in lista2
# Out:
# False

# %%
"t1" in lista2
# Out:
# True

# %%
lista1 == ['t1', 't2', 't3']
# Out:
# True

# %%
lista1 is ['t1', 't2', 't3']
# Out:
# False

# %% [markdown]
# ### 3. Las listas pueden contener objetos de diferentes tipos

# %% [markdown]
# Las listas puden contener una colección de objetos de diferentes tipos.

# %%
lista = [1, 2, "uno", "dos"]

# %%
print(lista)
# Out:
# [1, 2, 'uno', 'dos']

# %% [markdown]
# Una cosa interesante es que una lista puede llegar a contener una función.

# %%
def func():
    print("Hola mundo")

# %%
func
# Out:
# <function __main__.func()>

# %%
func()
# Out:
# Hola mundo

# %%
lista = ["texto1", "texto2", func]

# %%
print(lista)
# Out:
# ['texto1', 'texto2', <function func at 0x11fc3ce00>]

# %% [markdown]
# Los elementos de una lista no tienen que ser únicos. Puede repetirse el mismo elemento varias veces en la misma lista

# %%
lista = ["texto", "texto", "texto"]

# %%
print(lista)
# Out:
# ['texto', 'texto', 'texto']

# %% [markdown]
# ### 3. Acceso a los elementos de una lista

# %% [markdown]
# Los elementos de una lista pueden ser accedidos utilizando el concepto y la sintaxis de la indexación que se presentó cuando hablamos de strings.
#
# Todas las variaciones vistas en la sección de strings (indexing, slicing, stride) aplican a las listas.

# %% [markdown]
# #### Indexing

# %%
lista = ["text1", "text2", "text3", "text4", "text5"]

# %%
lista[0]
# Out:
# 'text1'

# %%
lista[-1]
# Out:
# 'text5'

# %% [markdown]
# #### Slicing

# %%
lista[2:4]
# Out:
# ['text3', 'text4']

# %%
lista[:3]
# Out:
# ['text1', 'text2', 'text3']

# %%
lista[2:]
# Out:
# ['text3', 'text4', 'text5']

# %% [markdown]
# #### Stride

# %%
lista[0:4:2]
# Out:
# ['text1', 'text3']

# %% [markdown]
# Una cosa interesante es que podemos utilizar el concepto de stride para darle la vuelta a una lista

# %%
lista
# Out:
# ['text1', 'text2', 'text3', 'text4', 'text5']

# %%
lista[::-1]
# Out:
# ['text5', 'text4', 'text3', 'text2', 'text1']

# %% [markdown]
# Una de las pocas construcciones sintácticas en cuanto a indexación que cambia entre los strings y las listas es `[:]`.

# %% [markdown]
# * Cuando utilizamos esta construcción sintáctica con un string, nos devuelve una referencia a ese mismo objeto:

# %%
texto = "Hola mundo"

# %%
texto[:]
# Out:
# 'Hola mundo'

# %%
texto[:] is texto
# Out:
# True

# %% [markdown]
# * Sin embargo, cuando lo utilizamos con una lista, nos devuelve una copia del objeto:

# %%
lista = [1, 2, 3, 4]

# %%
lista[:]
# Out:
# [1, 2, 3, 4]

# %%
lista[:] is lista
# Out:
# False

# %% [markdown]
# ### 4. Operaciones con listas

# %% [markdown]
# Como comentaba anteriormente, las listas soportan muchos de los operadores y funciones de Python por defecto presentados en los temas anteriores.

# %%
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]

# %%
lista1 + lista2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista1 * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
len(lista1)
# Out:
# 3

# %%
min(lista1)
# Out:
# 1

# %%
max(lista2)
# Out:
# 6

# %%
[1, 2, 3] + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 [1, 2, 3] + 4
#
# TypeError: can only concatenate list (not "int") to list

# %%
[1, 2, 3] + [4]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 5. Las listas se pueden anidar

# %% [markdown]
# Tal y como se ha presentado anteriormente, una lista puede contener cualquier tipo de objeto. Esto incluye otra lista. Una lista puede contener sublistas, que a su vez pueden contener sublistas, y así hasta una profundidad arbitraria.

# %%
lista = [1, [2, [3, 4], 5], 6]

# %%
lista[0]
# Out:
# 1

# %%
lista[1]
# Out:
# [2, [3, 4], 5]

# %% [markdown]
# Para aceder a los elementos de una sublista utilizamos la sintaxis `[][]`

# %%
lista[1][0]
# Out:
# 2

# %%
lista[1][1]
# Out:
# [3, 4]

# %%
lista[1][1][0]
# Out:
# 3

# %% [markdown]
# No hay límite en la cantidad de listas que podemos anidar, pueden ser tantas como soporte la memoria de nuestro sistema.

# %% [markdown]
# Es importante entender que los operadores aplicarán sobre la primera lista y no aplicarán de manera recursiva.

# %%
lista
# Out:
# [1, [2, [3, 4], 5], 6]

# %%
[3, 4] in lista
# Out:
# False

# %%
lista[1]
# Out:
# [2, [3, 4], 5]

# %%
[3, 4] in lista[1]
# Out:
# True

# %% [markdown]
# ### 6. Las listas son mutables

# %% [markdown]
# Al contrario que lo que veíamos cuando hablabamos de strings, las listas son estructuras mutables. Esto quiere decir que podemos modificar los elementos que forman parate de ellas.

# %%
lista = ["texto1", "texto2", "texto3"]

# %%
lista[0]
# Out:
# 'texto1'

# %%
lista[0] = "texto4"

# %%
lista
# Out:
# ['texto4', 'texto2', 'texto3']

# %% [markdown]
# También podemos eliminar elementos de una lista

# %%
del lista[0]

# %%
lista
# Out:
# ['texto2', 'texto3']

# %% [markdown]
# Podemos utilizar otros conceptos de indexación, como el slicing o el stride para modificar varios elementos de una lista

# %%
lista
# Out:
# ['texto2', 'texto3']

# %%
lista += ["texto4", "texto5", "texto6"]

# %%
lista
# Out:
# ['texto2', 'texto3', 'texto4', 'texto5', 'texto6']

# %%
lista[0:3]
# Out:
# ['texto2', 'texto3', 'texto4']

# %%
lista[0:3] = [1, 2, 3]

# %%
lista
# Out:
# [1, 2, 3, 'texto5', 'texto6']

# %% [markdown]
# El número de elementos seleccionados no tiene que ser igual a los asignados

# %%
lista[0:3]
# Out:
# [1, 2, 3]

# %%
lista[0:3] = [1, 2]

# %%
lista
# Out:
# [1, 2, 'texto5', 'texto6']

# %%
lista[2:2] = [3, 4, 5]

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 'texto5', 'texto6']

# %% [markdown]
# # Práctica

# %% [markdown]
# # Instrucciones
#
# 1. El programa tendrá una función llamada aumentar_biblioteca que recibirá un argumento: nuevo_libro.
#
# 2. Dentro de la función aumentar_biblioteca se debe leer un listado de títulos de libros que el usuario ya ha leído. Esta lista se encuentra almacenada en un archivo de texto libros.txt. Para leer la lista de libros, sigue los siguientes pasos:
#
#     a) Para leer el archivo libros.txt utiliza la función por defecto open(). Investiga en este enlace el funcionamiento de esta función: https://docs.python.org/3/library/functions.html#open
#
#     b) Convierte el archivo que acabas de leer a una lista utilizando la siguiente sentencia: libros = archivo.read().splitlines().
#
#     c) Termina la operación de lectura del archivo con la función archivo.close()
#
# 3. Dentro de la función, se debe añadir al final de la lista de libros el nuevo libro (nuevo_libro) especificado por el usuario.
#
# 4. La función debe devolver la lista completa de libros con el nuevo libro añadido.
#
# 5. El usuario debe mostrar por pantalla la lista completa de libros.
#
# 6. Adicionalmente, debe implementarse una nueva función llamada primer_libro_leido que imprimirá por pantalla el primer libro que el usuario ha leído y ha añadido a la lista de libros. Esta función recibirá como argumento la lista de libros y devolverá el primer libro de la lista.
#
# 7. El usuario debe mostrar por pantalla el primer libro de la lista.

# %% [markdown]
# # Resultado esperado
#
# La biblioteca de libros leídos es:
#
# ['Don Quijote de la Mancha', 'Orgullo y Prejuicio', 'Crimen y Castigo', 'Moby Dick', 'La Ilíada', 'El Gran Gatsby', 'Cien Años de Soledad', '1984', 'La Divina Comedia', 'Guerra y Paz', 'Las Aventuras de Huckleberry Finn']
#
# El primer libro que he leído es: "Don Quijote de la Mancha"
