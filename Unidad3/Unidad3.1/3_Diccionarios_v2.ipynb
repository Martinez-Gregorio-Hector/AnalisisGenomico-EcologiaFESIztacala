# %% [markdown]
# # Diccionarios

# %% [markdown]
# ### 1. ¿Qué son los diccionarios en Python?

# %% [markdown]
# Los diccionarios son un tipo de dato complejo y particular del lenguaje de programación Python que se corresponden con una colección de elementos clave-valor. Cada elemento clave-valor asocia la clave con un valor determinado.

# %% [markdown]
# Los diccionarios se representan dentro de python con el tipo de dato `dict`. La sintaxis utilizada para definir diccionarios es la siguiente: `{key:value, key2:value2, ..., keyn:valuen}`

# %%
dic = {
    "Nombre":"Santiago",
    "Apellido":"Hernandez",
    "Pais":"España",
    "Ciudad":"Madrid"
}

# %%
type(dic)
# Out:
# dict

# %%
print(dic)
# Out:
# {'Nombre': 'Santiago', 'Apellido': 'Hernandez', 'Pais': 'España', 'Ciudad': 'Madrid'}

# %%
# Otra forma de definir diccionarios con la funcion dict()
dic2 = dict(
    Nombre="Santiago",
    Apellido="Hernandez",
    Pais="España",
    Ciudad="Madrid"
)

# %%
print(dic2)
# Out:
# {'Nombre': 'Santiago', 'Apellido': 'Hernandez', 'Pais': 'España', 'Ciudad': 'Madrid'}

# %% [markdown]
# ### 2. Acceso a los elementos de un diccionario

# %% [markdown]
# Al contrario que las listas o las tuplas, los diccionarios no se acceden utilizando un índice. Los valores se acceden utilizando el nombre de la clave entre corchetes `[]`.

# %%
dic = {
    "Nombre":"Santiago",
    "Apellido":"Hernandez",
    "Pais":"España",
    "Ciudad":"Madrid"
}

# %%
dic['Nombre']
# Out:
# 'Santiago'

# %%
dic['Pais']
# Out:
# 'España'

# %%
dic['Edad']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dic['Edad']
#
# KeyError: 'Edad'

# %%
dic[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dic[0]
#
# KeyError: 0

# %% [markdown]
# Una de las cosas importantes que debemos tener en cuenta es que podemos utilizar cualquier objeto inmutable como clave de un diccionario, esto incluye números, strings, tuplas...

# %%
dic2 = {
    0: "cero",
    1: "uno",
    2: "dos",
    3: "tres"
}

# %%
dic2[0]
# Out:
# 'cero'

# %%
dic2[3]
# Out:
# 'tres'

# %%
dic3 = {
    ("uno", 1): "one",
    ("dos", 2): "two",
    ("tres", 3): "three"
}

# %%
dic3[("uno", 1)]
# Out:
# 'one'

# %%
dic3["dos", 2]
# Out:
# 'two'

# %% [markdown]
# ### 3. Elementos de un diccionario

# %% [markdown]
# Los diccionarios son estructuras que **pueden ser modificadas** y que **no respetan el orden** de los elementos, esto es como consecuencia de que sus elementos no se acceden a través de un índice númerico que determina su posición sino a través de una clave.

# %%
dic = {
    "Nombre":"Santiago",
    "Apellido":"Hernandez",
    "Pais":"España",
    "Ciudad":"Madrid"
}

# %%
dic["Nombre"] = "Pedro"

# %%
dic["Apellido"] = "Ramos"

# %%
print(dic)
# Out:
# {'Nombre': 'Pedro', 'Apellido': 'Ramos', 'Pais': 'España', 'Ciudad': 'Madrid'}

# %% [markdown]
# Una cosa interesante sobre los diccionarios es que podemos añadir nuevos elementos en la estructura cuando lo necesitemos.

# %%
print(dic)
# Out:
# {'Nombre': 'Pedro', 'Apellido': 'Ramos', 'Pais': 'España', 'Ciudad': 'Madrid'}

# %%
dic["Edad"] = 30

# %%
print(dic)
# Out:
# {'Nombre': 'Pedro', 'Apellido': 'Ramos', 'Pais': 'España', 'Ciudad': 'Madrid', 'Edad': 30}

# %% [markdown]
# Como podéis observar en el ejemplo anterior, los diccionarios permiten asignar diferentes tipos de datos a los valores que referencian las claves. Podemos asignar datos de cualquier tipo: números, strings, listas, tuplas... o incluso diccionarios.

# %%
dic2 = {
    "num":10,
    "str":"Hola mundo",
    "lista":[1, 2, 3, 4],
    "tupla":(1, 2, 3, 4),
    "dic":{"k1":"clave1", "k2":"clave2"}
}

# %%
dic2["str"]
# Out:
# 'Hola mundo'

# %%
dic2["lista"]
# Out:
# [1, 2, 3, 4]

# %%
dic2["lista"][2]
# Out:
# 3

# %%
dic2["dic"]
# Out:
# {'k1': 'clave1', 'k2': 'clave2'}

# %%
dic2["dic"]["k1"]
# Out:
# 'clave1'

# %% [markdown]
# Las claves del diccionario tampoco tienen que se del mismo tipo de dato.

# %%
dic3 = {
    1:"primer valor",
    "dos":"segundo valor",
    ("tres",):"tercer valor"
}

# %%
dic3[1]
# Out:
# 'primer valor'

# %%
dic3["dos"]
# Out:
# 'segundo valor'

# %%
dic3[("tres",)]
# Out:
# 'tercer valor'

# %% [markdown]
# **La restricción más importante que debemos de tener en cuenta cuando utilizamos diccionarios, es que no puede haber dos claves con el mismo nombre**

# %%
dic4 = {
    "key":"value1",
    "key":"value2"
}

# %%
dic4
# Out:
# {'key': 'value2'}

# %% [markdown]
# ### 4. Operaciones con diccionarios

# %% [markdown]
# Al igual que con las listas y el resto de tipos de datos complejos, podemos utilizar algunos de los operadores presentados en el tema anterior con los diccionarios.

# %%
dic1 = {
    "key1": "value1",
    "key2": "value2"
}

# %%
dic2 = {
    "key3": "value3",
    "key4": "value4"
}

# %%
dic1 is dic2
# Out:
# False

# %%
dic1 == dic2
# Out:
# False

# %%
dic1 == dic1
# Out:
# True

# %%
dic1 is dic1
# Out:
# True

# %%
dic1 + dic2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 dic1 + dic2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %% [markdown]
# # Ejercicio

# %% [markdown]
# ## Instrucciones
#
# 1. El programa tendrá una función llamada agregar_experiencia que recibe dos argumentos: perfil_laboral y nueva_experiencia.
#
#     a) perfil_laboral será un diccionario que contiene información personal del usuario: nombre, apellido, edad, ciudad, experiencias. Este último valor debe corresponderse con una lista que contendrá las experiencias laborales.
#
#     b) nueva_experiencia será una variable tipo string que indica el nuevo puesto de trabajo.
#
# 2. Dentro de la función agregar_experiencia, añade nueva_experiencia a la lista de experiencias en perfil_laboral y retorna el perfil_laboral como resultado de la función.
#
# 3. Crea otra función llamada generar_cv_reducido que tome perfil_laboral como argumento e imprima por pantalla un resumen del CV (con el formato especificado en las secciones siguientes), incluyendo la información personal y las experiencias laborales.
#
# 4. Fuera de las funciones añade una nueva experiencia laboral a tu perfil utilizando la función agregar_experiencia y llama a la función generar_cv_reducido tomando como argumento el resultado de la función agregar_experiencia para visualizar tu CV.

# %% [markdown]
# ## Resultado esperado
#
# CV de Ana Pérez
#
# Edad: 30, Ciudad: Madrid
#
# Experiencia: ['Ingeniera de software en XYZ Corp', 'Gerente de proyecto en ABC Inc']
