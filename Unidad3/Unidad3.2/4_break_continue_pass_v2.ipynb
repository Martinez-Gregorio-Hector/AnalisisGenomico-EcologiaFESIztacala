# %% [markdown]
# # Sentencias `break`, `continue` y `pass`

# %% [markdown]
# ### 1. ¿Qué es la sentencia `break`?

# %% [markdown]
# La sentencia `break` es una palabra reservada del lenguaje Python que podemos utilizar para terminar de manera inmediata la ejecución de una estructura de control de flujo `for` o `while`. El flujo de ejecución del programa pasará a la siguiente línea de código que se encuentre fuera de la estructura de control flujo.

# %%
colores = ["rojo", "verde", "azul"]

# %%
for color in colores:
    print(color)
# Out:
# rojo
# verde
# azul

# %%
for color in colores:
    print(color)
    break
print("Esto es una sentencia del bucle for")
# Out:
# rojo
# Esto es una sentencia del bucle for

# %%
num = 5

# %%
while num > 0:
    print(num)
    num -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
num = 5

# %%
while num > 0:
    print(num)
    num -= 1
    break
# Out:
# 2

# %% [markdown]
# Una de las cosas importantes que debemos tener en cuenta cuando estamos utilizando la sentencia `break` es que no se ejecutarán las líneas de código que pongamos en la claúsula `else`.

# %%
for color in colores:
    print(color)
    break
else:
    print("Ejecución en la claúsula else")
# Out:
# rojo

# %% [markdown]
# ### 2. ¿Qué es la sentencia `continue`?

# %% [markdown]
# La sentencia `continue` es otra palabra reservada de Python sin embargo, a diferencia de la sentencia `break`, no termina la ejecución completa de los bucles `for` y `while` sino que termina únicamente la ejecución de la iteración actual.

# %%
colores = ["azul", "verde", "rojo"]

# %%
for color in colores:
    print(color)
# Out:
# azul
# verde
# rojo

# %%
for color in colores:
    print(color)
    continue
# Out:
# azul
# verde
# rojo

# %%
for color in colores:
    if color == "verde":
        continue
    print(color)
# Out:
# azul
# rojo

# %%
num = 5

# %%
while num > 0:
    num -= 1
    if num == 2:
        continue    
    print(num)
# Out:
# 4
# 3
# 1
# 0

# %% [markdown]
# ### 3. ¿Qué es la sentencia `pass`?

# %% [markdown]
# La sentencia `pass` es una palabra reservada de Python que nos permite definir el esqueleto de diferentes estructuras de diferentes tipos (funciones, if, while, for...) sin indicarle ninguna línea de código en el cuerpo de la estructura.

# %%
def funcion():
# Out:
#   Cell In[55], line 1
#     def funcion():
#                   ^
# SyntaxError: incomplete input

# %%
def funcion():
    pass

# %%
colores = ["azul", "verde", "rojo"]

# %%
for color in colores:
    # Aqui voy a hacer algo que todavia no se
# Out:
#   Cell In[69], line 2
#     # Aqui voy a hacer algo que todavia no se
#                                              ^
# SyntaxError: incomplete input

# %%
for color in colores:
    # Aqui voy a hacer algo que todavia no se
    pass

# %% [markdown]
# ## Ejercicio
#
# En este caso práctico se propone al alumno "Programar el software de un despertador". Para ello debe hacer uso de las sentencias de control de flujo vistas en clases anteriores en combinación con las sentencias break, continue y pass.
#
# ## Instrucciones
#
# 1. Define una función llamada simulador_alarma que acepte un parámetro: tiempo_total. Este parámetro indica la cantidad total de "segundos" (iteraciones) que el simulador debe ejecutarse.
#
# 2. Dentro de la función, inicializa una variable segundo_actual en 0. Esta variable funcionará como contador para simular el paso del tiempo.
#
# 3. Implementa un bucle while que continúe ejecutándose hasta que segundo_actual alcance el valor de tiempo_total.
#
# 4. En cada iteración del bucle, incrementa segundo_actual en 1 para simular el paso de un segundo.
#
# 5. Utiliza la sentencia continue para "pausar" la alarma cada 10 "segundos".
#
# 6. Asegúrate de imprimir un mensaje cada vez que se "pausa" la alarma, indicando que se ha omitido un segundo específico.
#
# 7. Imprime un mensaje en cada iteración que no se pausa para indicar que la alarma está activada y para mostrar el segundo actual.
#
# 8. Emplea la sentencia break para terminar el bucle y finalizar la simulación de la alarma cuando segundo_actual alcance el valor de tiempo_total.
#
# 9. Imprime un mensaje final para indicar que la alarma se ha desactivado, especificando el total de "segundos" que estuvo activa.
#
# 10. Invoca la función simulador_alarma.
#
# ## Resultado esperado
#
# Alarma activada, segundo actual: 1
#
# Alarma activada, segundo actual: 2
#
# Alarma activada, segundo actual: 3
#
# Alarma activada, segundo actual: 4
#
# Alarma activada, segundo actual: 5
#
# Alarma activada, segundo actual: 6
#
# Alarma activada, segundo actual: 7
#
# Alarma activada, segundo actual: 8
#
# Alarma activada, segundo actual: 9
#
# Omitiendo alarma en segundo 10
#
# Alarma activada, segundo actual: 11
#
# Alarma activada, segundo actual: 12
#
# Alarma activada, segundo actual: 13
#
# Alarma activada, segundo actual: 14
#
# Alarma activada, segundo actual: 15
#
# Alarma activada, segundo actual: 16
#
# Alarma activada, segundo actual: 17
#
# Alarma activada, segundo actual: 18
#
# Alarma activada, segundo actual: 19
#
# Omitiendo alarma en segundo 20
#
# Alarma activada, segundo actual: 21
#
# Alarma desactivada a los 21 segundos
