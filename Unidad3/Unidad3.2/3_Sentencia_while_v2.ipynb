# %% [markdown]
# # Sentencia `while`

# %% [markdown]
# ### 1. ¿Qué es la sentencia `while`?

# %% [markdown]
# La sentencia de control de flujo `while` es otra de las estructuras fundamentales de cualquier lenguaje de programación, incluido Python.
#
# **Esta estructura nos permite implementar sentencias en Python que se repitan un número infinito de veces.**
#
# La sintaxis utilizada para definir la sentencia `while` es la siguiente:
# ```
# while <expresión>:
#     <sentencia(s)>
# ```
#
# `<sentencia(s)>` es el bloque de sentencias en Python que se ejecutará de manera indefinida hasta que no se cumpla la expresión.
#
# `<expresión>` es una expresión evaluada en un contexto booleano. El resultado de evaluar esta expresión debe ser `True` o `False`. Controla la ejecución del bucle `while`.

# %%
num = 10

# %%
while num > 0:
    print(num)

# %%
while num > 0:
    num -= 1
    print(num)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ### 2. Claúsula else

# %% [markdown]
# Al igual que con el bucle `for`, la sentencia `while` también permite el uso de una claúsula `else`.

# %%
num = 5

# %%
while num > 0:
    num -= 1
    print(num)
else:
    print("Sentencia final del bucle")
# Out:
# Sentencia final del bucle

# %% [markdown]
# ### 3. Bucles infinitos

# %% [markdown]
# Una de las características importantes de los bucles `while` es que pueden ejecutarse de manera infinita. Si no se realiza un control adecuado de la expresión que se evalúa, el bucle puede ejecutarse de manera indefinida hasta que se consuman los recursos de nuestro sistema.

# %%
num = 5

# %%
while num > 0:
    print("En ejecución...")
# Out:
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# En ejecución...
# ...

# %% [markdown]
# ### 4. Bucle `while` en una línea

# %% [markdown]
# Al igual que con otras estructuras de Python, los bucles `while` también pueden implementarse utilizando una única línea de código.

# %%
num = 10

# %%
while num > 0: num -= 1; print(num)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# ## Ejercicio
#
# En este caso práctico se propone al alumno la "Creación del software de un ascensor". Para ello, debe hacer uso de la sentencia de control de flujo While en Python.
#
# ## Instrucciones
#
# 1. Implementa una función mover_ascensor que reciba dos argumentos: piso_actual y piso_deseado
#
# 2. Dentro de la función implementa un bucle while para mover el ascensor a cada piso, uno por uno.
#
# 3. El bucle while debe comprobar que el piso actual es distinto al deseado, para conocer si el usuario ha llegado.
#
# 4. Dentro del bucle while debe comprobarse si el piso actual es mayor o menor que el piso deseado, para conocer si el ascensor debe subir o bajar.
#
# 5. En caso de que el ascensor deba subir, se imprimirá por pantalla un mensaje que indique a que piso está subiendo el ascensor y en qué piso se encuentra en ese momento.
#
# 6. Por último, la variable piso_actual deberá incrementarse en 1.
#
# 7. En caso de que el ascensor deba bajar, se seguirá el proceso inverso con los mismos pasos que para la subida, restando 1 a la variable piso_actual.
#
# 8. Finalmente, al terminar el bucle while, se imprimirá un mensaje indicando que se ha llegado al piso deseado.
#
# 9. Invoca la función mover_ascensor proporcionándole un piso actual y un piso deseado.
#
# ## Resultado esperado
#
# Subiendo al piso 6. Piso actual: 2
#
# Subiendo al piso 6. Piso actual: 3
#
# Subiendo al piso 6. Piso actual: 4
#
# Subiendo al piso 6. Piso actual: 5
#
# Piso 6 alcanzado
