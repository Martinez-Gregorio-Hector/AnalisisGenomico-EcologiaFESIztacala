# %% [markdown]
# # Variables

# %% [markdown]
# ### 1. Variables en Python

# %% [markdown]
# Una variable es un elemento de un lenguaje de programación que tiene asignado un valor determinado. Para crear una variable en Python se le debe proporcionar un nombre y asignarle un valor utilizando el símbolo `=`

# %%
var = "Hola mundo"

# %%
print(var)

# %% [markdown]
# El valor asignado a una variable puede cambiar a lo largo del programa escrito en Python

# %%
var = "Adios mundo"

# %%
print(var)

# %% [markdown]
# ### 2. Asignación múltiple

# %% [markdown]
# Otra de las cosas que podemos hacer con las variables en Python es asignar una variable a otra variable diferente.

# %%
var = "Hola mundo"

# %%
var2 = var

# %%
print(var2)

# %% [markdown]
# En el caso que se acaba de mostrar en las celdas anteriores, la variable `var` y `var2` apuntan a la misma cadena de texto `Hola mundo`

# %% [markdown]
# ### 3. Sintaxis de las variables en Python

# %% [markdown]
# Tal y como se ha introducido en la primera sección, para definir variables en Python se debe cumplir con las reglas sintácticas definidas por el leguaje. A continuación se indican las reglas que debemos cumplir cuando definimos el nombre de una variable:

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
# 1. Los nombres de las variables en Python pueden tener cualquier longitud y pueden consistir en letras mayúsculas y minúsculas (A-Z, a-z), dígitos (0-9) y el carácter de subrayado (_)
# </div>

# %%
_var = "Hola mundo"

print(_var)

# %%
vAr = "Hola mundo"

print(vAr)

# %%
var_2 = "Hola mundo"

print(var_2)

# %% [markdown]
# Si no se cumple con estas reglas definidas en la sintaxis de Python, el intérprete de Python emitirá un error a la hora de ejecutar la sentencia

# %%
var& = "Hola mundo"

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
# 2. Aunque el nombre de una variable puede contener dígitos, el primer carácter de un nombre de variable no puede ser un dígito.
# </div>

# %%
2var = "Hola mundo"

# %% [markdown]
# <div style="background-color:#D9EEFF;color:black;padding:2%;">
# 3. El nombre de las variables en Python es sensible a mayúsculas y minúsculas
# </div>

# %%
Var3 = "Hola mundo"

# %%
print(var3)

# %%
# Ejercicio

# %% [markdown]
# ## PRACTICA VARIABLES
#
# ## OBJETO
#
# Crear un "Menú del Día de un Restaurante Gourmet" usando variables y la función print para mostrar los platos en la consola.
#
# ## INSTRUCCIONES
#
#
# 1. Escribe un programa en Python que utilice variables para almacenar información sobre diferentes platos y luego usa la función print para mostrar un menú gourmet.
# 2. El menú debe contener tres secciones: Entrante, Plato Principal y Postre.
# 3. Para cada sección, define dos variables:
#
# ### a) Una para el nombre del plato: nombre_entrante, nombre_principal y nombre_postre.
#
# ### b) Otra para el precio: precio_entrante, precio_principal y precio_postre.
# 4. Usa múltiples llamadas a la función print para mostrar primero el nombre del plato y luego su precio en líneas separadas.
#
# Importante: Las variables que definas para crear el menú tienen que tener el mismo nombre que se muestra en el punto 3: nombre_entrante, precio_entrante, nombre_principal, precio_principal, nombre_postre y precio_postre.
#
#
#
# ## Resultado esperado
#
# Menú del Día - Restaurante Gourmet
#
# -- Entrante --
#
# Sopa de trufas
#
# Precio:
#
# 12 euros
#
# -- Plato Principal --
#
# Filete Mignon con salsa de vino tinto
#
# Precio:
#
# 30 euros
#
# -- Postre --
#
# Tiramisú casero
#
# Precio:
#
# 8 euros
